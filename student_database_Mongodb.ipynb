# %%
# !pip install pymongo
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pymongo in /usr/local/lib/python3.7/dist-packages (4.3.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from pymongo) (2.2.1)

# %%
! pip install dnspython
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: dnspython in /usr/local/lib/python3.7/dist-packages (2.2.1)

# %%
from pymongo import MongoClient

# %%
Elan=MongoClient("mongodb://Elan:Data1234@ac-gi8oirz-shard-00-00.aeiyllz.mongodb.net:27017,ac-gi8oirz-shard-00-01.aeiyllz.mongodb.net:27017,ac-gi8oirz-shard-00-02.aeiyllz.mongodb.net:27017/?ssl=true&replicaSet=atlas-124qwt-shard-0&authSource=admin&retryWrites=true&w=majority")

# %%
Elan
# Out:
# MongoClient(host=['ac-gi8oirz-shard-00-00.aeiyllz.mongodb.net:27017', 'ac-gi8oirz-shard-00-01.aeiyllz.mongodb.net:27017', 'ac-gi8oirz-shard-00-02.aeiyllz.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, replicaset='atlas-124qwt-shard-0', authsource='admin', retrywrites=True, w='majority', tls=True)

# %%
Elan.list_database_names()
# Out:
# ['Elan',
#  'GUVI',
#  'sample_airbnb',
#  'sample_analytics',
#  'sample_geospatial',
#  'sample_guides',
#  'sample_mflix',
#  'sample_restaurants',
#  'sample_supplies',
#  'sample_training',
#  'sample_weatherdata',
#  'stu',
#  'stud',
#  'students_database',
#  'admin',
#  'local']

# %%
#creating database
database_1=Elan["students_database"]
col_1=database_1["collections"]
rec_1=col_1["collections"]

# %%
import json
dic=[]
with open(r"/content/students.json") as s:
    for j in s:
        z = json.loads(j)
        dic.append(z)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-2c1a792d4050> in <module>
#       1 import json
#       2 dic=[]
# ----> 3 with open(r"/content/students.json") as s:
#       4     for j in s:
#       5         z = json.loads(j)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/students.json'

# %%
#insert collection
print("Record and collection updated")
rec_1.insert_many(dic)
# Out:
# Record and collection updated
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-730f434aec6b> in <module>
#       1 #insert collection
#       2 print("Record and collection updated")
# ----> 3 rec_1.insert_many(dic)
#
# /usr/local/lib/python3.7/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     103                 with _TimeoutContext(timeout):
#     104                     return func(self, *args, **kwargs)
# --> 105         return func(self, *args, **kwargs)
#     106
#     107     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.7/dist-packages/pymongo/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     689             or not documents
#     690         ):
# --> 691             raise TypeError("documents must be a non-empty list")
#     692         inserted_ids: List[ObjectId] = []
#     693
#
# TypeError: documents must be a non-empty list

# %%
import pandas as pd
df_1=pd.DataFrame(dic)
df_1
# Out:
#      _id              name                                             scores
# 0      0        aimee Zank  [{'score': 1.463179736705023, 'type': 'exam'},...
# 1      1  Aurelia Menendez  [{'score': 60.06045071030959, 'type': 'exam'},...
# 2      2       Corliss Zuk  [{'score': 67.03077096065002, 'type': 'exam'},...
# 3      3        Bao Ziglar  [{'score': 71.64343899778332, 'type': 'exam'},...
# 4      4  Zachary Langlais  [{'score': 78.68385091304332, 'type': 'exam'},...
# ..   ...               ...                                                ...
# 195  195     Linnie Weigel  [{'score': 52.44578368517977, 'type': 'exam'},...
# 196  196  Santiago Dollins  [{'score': 52.04052571137036, 'type': 'exam'},...
# 197  197     Tonisha Games  [{'score': 38.51269589995049, 'type': 'exam'},...
# 198  198    Timothy Harrod  [{'score': 11.9075674046519, 'type': 'exam'}, ...
# 199  199        Rae Kohout  [{'score': 82.11742562118049, 'type': 'exam'},...
#
# [200 rows x 3 columns]

# %%
name=[]
score1=[]
score2=[]
score3=[]

for i in range(len(dic)):
  name.append(dic[i]['name'])
  score1.append(dic[i]['scores'][0]['score'])
  score2.append(dic[i]['scores'][1]['score'])
  score3.append(dic[i]['scores'][2]['score'])

# %%
#For User Simplicity Scores Column is Covereted into Seprate Collection

res=zip(name,score1,score2,score3)
df_2=pd.DataFrame(res,columns=['name','exam_score', 'quiz_score', 'homework_score'])
df_2
# Out:
#                  name  exam_score  quiz_score  homework_score
# 0          aimee Zank    1.463180   11.782733       35.874035
# 1    Aurelia Menendez   60.060451   52.797907       71.761334
# 2         Corliss Zuk   67.030771    6.301852       66.283447
# 3          Bao Ziglar   71.643439   24.802213       42.261471
# 4    Zachary Langlais   78.683851   90.296310       34.416201
# ..                ...         ...         ...             ...
# 195     Linnie Weigel   52.445784   90.777505       11.750084
# 196  Santiago Dollins   52.040526   33.633001       78.792574
# 197     Tonisha Games   38.512696   31.162876       79.158564
# 198    Timothy Harrod   11.907567   20.518800       64.856504
# 199        Rae Kohout   82.117426   49.612955       28.868237
#
# [200 rows x 4 columns]

# %%
#Function for Exporting Data Frame Into MongoDB
def exportMongo(data):
  data.reset_index(drop=True,inplace=True)
  data_dict=data.to_dict("records")
  return data_dict

# %%
#Converting Scores Column into Seprate Column for User Simplicity

col_2=database_1["student_scores"]
rec_2=col_2["scores"]
rec_2.insert_many(exportMongo(df_2))

# %%
for i in rec_2.find({},{'_id':0,'index':0}):
  print(i)
# Out:
# {'name': 'aimee Zank', 'exam_score': 1.463179736705023, 'quiz_score': 11.78273309957772, 'homework_score': 35.8740349954354}
# {'name': 'Aurelia Menendez', 'exam_score': 60.06045071030959, 'quiz_score': 52.79790691903873, 'homework_score': 71.76133439165544}
# {'name': 'Corliss Zuk', 'exam_score': 67.03077096065002, 'quiz_score': 6.301851677835235, 'homework_score': 66.28344683278382}
# {'name': 'Bao Ziglar', 'exam_score': 71.64343899778332, 'quiz_score': 24.80221293650313, 'homework_score': 42.26147058804812}
# {'name': 'Zachary Langlais', 'exam_score': 78.68385091304332, 'quiz_score': 90.2963101368042, 'homework_score': 34.41620148042529}
# {'name': 'Wilburn Spiess', 'exam_score': 44.87186330181261, 'quiz_score': 25.72395114668016, 'homework_score': 63.42288310628662}
# {'name': 'Jenette Flanders', 'exam_score': 37.32285459166097, 'quiz_score': 28.32634976913737, 'homework_score': 81.57115318686338}
# {'name': 'Salena Olmos', 'exam_score': 90.37826509157176, 'quiz_score': 42.48780666956811, 'homework_score': 96.52986171633331}
# {'name': 'Daphne Zheng', 'exam_score': 22.13583712862635, 'quiz_score': 14.63969941335069, 'homework_score': 75.94123677556644}
# {'name': 'Sanda Ryba', 'exam_score': 97.00509953654694, 'quiz_score': 97.80449632538915, 'homework_score': 25.27368532432955}
# {'name': 'Denisha Cast', 'exam_score': 45.61876862259409, 'quiz_score': 98.35723209418343, 'homework_score': 55.90835657173456}
# {'name': 'Marcus Blohm', 'exam_score': 78.42617835651868, 'quiz_score': 82.58372817930675, 'homework_score': 87.49924733328717}
# {'name': 'Quincy Danaher', 'exam_score': 54.29841278520669, 'quiz_score': 85.61270164694737, 'homework_score': 80.40732356118075}
# {'name': 'Jessika Dagenais', 'exam_score': 90.47179954427436, 'quiz_score': 90.3001402468489, 'homework_score': 95.17753772405909}
# {'name': 'Alix Sherrill', 'exam_score': 25.15924151998215, 'quiz_score': 68.64484047692098, 'homework_score': 24.68462152686763}
# {'name': 'Tambra Mercure', 'exam_score': 69.1565022533158, 'quiz_score': 3.311794422000724, 'homework_score': 45.03178973642521}
# {'name': 'Dodie Staller', 'exam_score': 7.772386442858281, 'quiz_score': 31.84300235104542, 'homework_score': 80.52136407989194}
# {'name': 'Fletcher Mcconnell', 'exam_score': 39.41011069729274, 'quiz_score': 81.13270307809924, 'homework_score': 97.70116640402922}
# {'name': 'Verdell Sowinski', 'exam_score': 62.12870233109035, 'quiz_score': 84.74586220889356, 'homework_score': 81.58947824932574}
# {'name': 'Gisela Levin', 'exam_score': 44.51211101958831, 'quiz_score': 0.6578497966368002, 'homework_score': 93.36341655949683}
# {'name': 'Tressa Schwing', 'exam_score': 42.17439799514388, 'quiz_score': 71.99314840599558, 'homework_score': 81.23972632069464}
# {'name': 'Rosana Vales', 'exam_score': 46.2289476258328, 'quiz_score': 98.34164225207036, 'homework_score': 36.18769746805938}
# {'name': 'Margart Vitello', 'exam_score': 75.04996547553947, 'quiz_score': 10.23046475899236, 'homework_score': 96.72520512117761}
# {'name': 'Tamika Schildgen', 'exam_score': 45.65432764125526, 'quiz_score': 64.32927049658846, 'homework_score': 83.53933351660562}
# {'name': 'Jesusa Rickenbacker', 'exam_score': 86.0319702155683, 'quiz_score': 1.967495200433389, 'homework_score': 61.10861071547914}
# {'name': 'Rudolph Domingo', 'exam_score': 74.75289335591543, 'quiz_score': 38.5413647805495, 'homework_score': 35.2554340953413}
# {'name': 'Jonie Raby', 'exam_score': 19.17861192576963, 'quiz_score': 76.3890359749654, 'homework_score': 44.39605672647002}
# {'name': 'Edgar Sarkis', 'exam_score': 8.606983261043888, 'quiz_score': 58.71180464203724, 'homework_score': 15.33726210596508}
# {'name': 'Laureen Salomone', 'exam_score': 3.677565278992456, 'quiz_score': 7.119462599229987, 'homework_score': 82.87308922617427}
# {'name': 'Gwyneth Garling', 'exam_score': 48.36644963899371, 'quiz_score': 10.37827022865908, 'homework_score': 93.26639335532833}
# {'name': 'Kaila Deibler', 'exam_score': 15.89771199662455, 'quiz_score': 56.93965183412178, 'homework_score': 66.64493295066322}
# {'name': 'Tandra Meadows', 'exam_score': 24.90138146001744, 'quiz_score': 28.8266541837344, 'homework_score': 97.16831550665721}
# {'name': 'Gwen Honig', 'exam_score': 87.14345376886205, 'quiz_score': 99.45824441135635, 'homework_score': 76.66460454219344}
# {'name': 'Sadie Jernigan', 'exam_score': 73.15861249943812, 'quiz_score': 2.987718065941702, 'homework_score': 82.54104198590488}
# {'name': 'Carli Belvins', 'exam_score': 7.112266875518214, 'quiz_score': 67.734668378287, 'homework_score': 88.99855402666871}
# {'name': 'Synthia Labelle', 'exam_score': 27.22049103148209, 'quiz_score': 31.28760039265919, 'homework_score': 79.23285425688643}
# {'name': 'Eugene Magdaleno', 'exam_score': 73.055900093666, 'quiz_score': 79.85621560462026, 'homework_score': 66.09143669040472}
# {'name': 'Meagan Oakes', 'exam_score': 86.06759716616264, 'quiz_score': 79.45097452834857, 'homework_score': 28.41090281547689}
# {'name': 'Richelle Siemers', 'exam_score': 34.64373397163318, 'quiz_score': 91.46799649446983, 'homework_score': 56.12615074082559}
# {'name': 'Mariette Batdorf', 'exam_score': 0.04381116979284005, 'quiz_score': 90.25774974259562, 'homework_score': 65.88612319625227}
# {'name': 'Rachell Aman', 'exam_score': 84.53009035375172, 'quiz_score': 25.25568126160764, 'homework_score': 70.42062575402956}
# {'name': 'Aleida Elsass', 'exam_score': 28.02518041693717, 'quiz_score': 95.25243105389065, 'homework_score': 68.05980405338909}
# {'name': 'Kayce Kenyon', 'exam_score': 44.62441703708117, 'quiz_score': 27.38208798553111, 'homework_score': 97.43587143437509}
# {'name': 'Ernestine Macfarland', 'exam_score': 15.29147856258362, 'quiz_score': 78.40698797039501, 'homework_score': 31.03031764716336}
# {'name': 'Houston Valenti', 'exam_score': 98.06441387027331, 'quiz_score': 0.8760893342659504, 'homework_score': 15.2177618920215}
# {'name': 'Terica Brugger', 'exam_score': 42.1011312120801, 'quiz_score': 41.73654145887228, 'homework_score': 18.91287189072117}
# {'name': 'Lady Lefevers', 'exam_score': 16.89237820123443, 'quiz_score': 65.97505910406456, 'homework_score': 48.42527123437286}
# {'name': 'Kurtis Jiles', 'exam_score': 92.96916908741805, 'quiz_score': 22.86854192921203, 'homework_score': 31.89793879453222}
# {'name': 'Barbera Lippman', 'exam_score': 35.43490750932609, 'quiz_score': 97.42074160188449, 'homework_score': 74.1092960902528}
# {'name': 'Dinah Sauve', 'exam_score': 96.64807532447064, 'quiz_score': 14.56470882270576, 'homework_score': 72.00519420743191}
# {'name': 'Alica Pasley', 'exam_score': 19.38544736721771, 'quiz_score': 88.70752686639557, 'homework_score': 60.62755218680213}
# {'name': 'Elizabet Kleine', 'exam_score': 86.81245449846962, 'quiz_score': 36.196443334522, 'homework_score': 77.94001750905642}
# {'name': 'Tawana Oberg', 'exam_score': 80.59006098671075, 'quiz_score': 93.28438118988183, 'homework_score': 93.12134003887978}
# {'name': 'Malisa Jeanes', 'exam_score': 33.44580005842922, 'quiz_score': 7.172746439960975, 'homework_score': 80.53328849494751}
# {'name': 'Joel Rueter', 'exam_score': 87.53636893952853, 'quiz_score': 92.70974674256513, 'homework_score': 61.79032586247813}
# {'name': 'Tresa Sinha', 'exam_score': 94.93136959210354, 'quiz_score': 72.32226123565266, 'homework_score': 77.248768811767}
# {'name': 'Danika Loeffler', 'exam_score': 21.54531707142236, 'quiz_score': 41.75962115078149, 'homework_score': 55.70195462204016}
# {'name': 'Chad Rahe', 'exam_score': 40.84572027366789, 'quiz_score': 29.22733629679561, 'homework_score': 93.12112348179406}
# {'name': 'Joaquina Arbuckle', 'exam_score': 28.66671659815553, 'quiz_score': 40.48858382583742, 'homework_score': 51.51393116681172}
# {'name': 'Vinnie Auerbach', 'exam_score': 95.45508256300009, 'quiz_score': 7.512188017365151, 'homework_score': 28.5905754294006}
# {'name': 'Dusti Lemmond', 'exam_score': 17.27725327681863, 'quiz_score': 83.24439414725833, 'homework_score': 81.84258722611811}
# {'name': 'Grady Zemke', 'exam_score': 51.91561300267121, 'quiz_score': 50.08349374829509, 'homework_score': 95.34139273570386}
# {'name': 'Vina Matsunaga', 'exam_score': 51.38190070034149, 'quiz_score': 34.63479282877322, 'homework_score': 46.27059093183421}
# {'name': 'Rubie Winton', 'exam_score': 7.176062073558509, 'quiz_score': 46.32426882511162, 'homework_score': 19.24312817599633}
# {'name': 'Whitley Fears', 'exam_score': 89.61845831842888, 'quiz_score': 82.44879156010508, 'homework_score': 96.57912148645883}
# {'name': 'Gena Riccio', 'exam_score': 67.58395308948619, 'quiz_score': 67.2413500951588, 'homework_score': 42.93471779899529}
# {'name': 'Kim Xu', 'exam_score': 19.96531774799065, 'quiz_score': 17.52966217224916, 'homework_score': 57.32983091095816}
# {'name': 'Merissa Mann', 'exam_score': 75.1949733626123, 'quiz_score': 52.56522605123723, 'homework_score': 94.67518167209815}
# {'name': 'Jenise Mcguffie', 'exam_score': 40.15210496060384, 'quiz_score': 90.60219950183566, 'homework_score': 51.58720341010564}
# {'name': 'Cody Strouth', 'exam_score': 4.784730508547719, 'quiz_score': 99.80348240553108, 'homework_score': 97.89665889862901}
# {'name': 'Harriett Velarde', 'exam_score': 33.7733570443736, 'quiz_score': 96.05228578589255, 'homework_score': 46.24926696413032}
# {'name': 'Kam Senters', 'exam_score': 81.56497719010976, 'quiz_score': 5.247410853581524, 'homework_score': 92.10078400854972}
# {'name': 'Leonida Lafond', 'exam_score': 92.10605086888438, 'quiz_score': 32.66022211621239, 'homework_score': 82.15588797092647}
# {'name': 'Devorah Smartt', 'exam_score': 69.60160495436016, 'quiz_score': 6.931507591998553, 'homework_score': 55.66005349294464}
# {'name': 'Leola Lundin', 'exam_score': 31.62936464207764, 'quiz_score': 91.28658941188532, 'homework_score': 93.71671632774428}
# {'name': 'Tonia Surace', 'exam_score': 80.93655069496523, 'quiz_score': 79.54620208144452, 'homework_score': 41.34308724166419}
# {'name': 'Adrien Renda', 'exam_score': 57.24794864351232, 'quiz_score': 19.5118228072558, 'homework_score': 70.71043448913191}
# {'name': 'Efrain Claw', 'exam_score': 55.41266579085205, 'quiz_score': 31.30359328252952, 'homework_score': 88.73134194093676}
# {'name': 'Len Treiber', 'exam_score': 21.21850173315791, 'quiz_score': 13.2282768150266, 'homework_score': 82.49842801247594}
# {'name': 'Mariela Sherer', 'exam_score': 61.20158144877323, 'quiz_score': 52.75657259917104, 'homework_score': 90.97004773806381}
# {'name': 'Echo Pippins', 'exam_score': 27.77924608896123, 'quiz_score': 85.1861976198818, 'homework_score': 92.50671800180454}
# {'name': 'Linnie Weigel', 'exam_score': 66.0349256424749, 'quiz_score': 67.57096025532985, 'homework_score': 38.33608066073369}
# {'name': 'Santiago Dollins', 'exam_score': 33.48242310776701, 'quiz_score': 60.49199094204558, 'homework_score': 87.02564768982076}
# {'name': 'Tonisha Games', 'exam_score': 29.13833807032966, 'quiz_score': 35.25054111123917, 'homework_score': 66.73047056293319}
# {'name': 'Timothy Harrod', 'exam_score': 93.23020013495737, 'quiz_score': 49.06010347848443, 'homework_score': 74.00788699415295}
# {'name': 'Rae Kohout', 'exam_score': 63.86894250781692, 'quiz_score': 55.81549538273672, 'homework_score': 59.13566011309437}
# {'name': 'Brain Lachapelle', 'exam_score': 2.013473187690951, 'quiz_score': 45.01802394825918, 'homework_score': 88.04712649447521}
# {'name': 'Toshiko Sabella', 'exam_score': 21.05570509531929, 'quiz_score': 26.43387483146958, 'homework_score': 42.80331214002496}
# {'name': 'Keesha Papadopoulos', 'exam_score': 82.35397321850031, 'quiz_score': 3.064361273717464, 'homework_score': 98.46867828216399}
# {'name': 'Cassi Heal', 'exam_score': 43.04310994985133, 'quiz_score': 0.006247360551892012, 'homework_score': 63.88558436723092}
# {'name': 'Osvaldo Hirt', 'exam_score': 67.44931456608883, 'quiz_score': 41.77986504201782, 'homework_score': 76.30879472084027}
# {'name': 'Ty Barbieri', 'exam_score': 38.43781607953586, 'quiz_score': 95.70340794272111, 'homework_score': 72.80272364761178}
# {'name': 'Ta Sikorski', 'exam_score': 30.02140506101446, 'quiz_score': 23.89164976236439, 'homework_score': 61.82907698626848}
# {'name': 'Lucinda Vanderburg', 'exam_score': 27.55843343656866, 'quiz_score': 11.45699271327768, 'homework_score': 75.53546873615787}
# {'name': 'Darby Wass', 'exam_score': 6.867644836612586, 'quiz_score': 63.4908039680606, 'homework_score': 85.41865347441522}
# {'name': 'Omar Bowdoin', 'exam_score': 8.58858127638702, 'quiz_score': 88.40377630359677, 'homework_score': 25.71387474240768}
# {'name': 'Milan Mcgavock', 'exam_score': 69.11554341921843, 'quiz_score': 10.2027724707151, 'homework_score': 24.87545552041663}
# {'name': 'Maren Scheider', 'exam_score': 94.4329121733663, 'quiz_score': 77.28263690107663, 'homework_score': 59.46326216544371}
# {'name': 'Carli Ector', 'exam_score': 88.18040268522668, 'quiz_score': 60.3111085581054, 'homework_score': 96.33612053785647}
# {'name': 'Jaclyn Morado', 'exam_score': 70.27627082122453, 'quiz_score': 56.78470387064279, 'homework_score': 47.48518298423097}
# {'name': 'Demarcus Audette', 'exam_score': 47.42608580155614, 'quiz_score': 44.83416623719906, 'homework_score': 39.01726616178844}
# {'name': 'Tania Hulett', 'exam_score': 21.84617015735916, 'quiz_score': 53.8568257735492, 'homework_score': 79.60533635579307}
# {'name': 'Mercedez Garduno', 'exam_score': 49.52877007656483, 'quiz_score': 44.55505066212384, 'homework_score': 81.50869746632009}
# {'name': 'Fleta Duplantis', 'exam_score': 84.37799696030743, 'quiz_score': 15.95792143439528, 'homework_score': 77.80745176713172}
# {'name': 'Brittny Warwick', 'exam_score': 69.54399888097534, 'quiz_score': 82.00469934215849, 'homework_score': 95.96446106607902}
# {'name': 'Shin Allbright', 'exam_score': 62.28388941877533, 'quiz_score': 85.26863799439475, 'homework_score': 88.9947941542333}
# {'name': 'Karry Petrarca', 'exam_score': 3.677125771067413, 'quiz_score': 40.39799056667404, 'homework_score': 14.38347127905983}
# {'name': 'Beckie Millington', 'exam_score': 69.52419218194589, 'quiz_score': 24.85411404016219, 'homework_score': 34.92039455520659}
# {'name': 'Mikaela Meidinger', 'exam_score': 63.75595052560389, 'quiz_score': 59.52298111997963, 'homework_score': 88.66481441499843}
# {'name': 'Flora Duell', 'exam_score': 40.68238966626067, 'quiz_score': 46.77972040308903, 'homework_score': 69.29400057020965}
# {'name': 'Nobuko Linzey', 'exam_score': 67.40792606687442, 'quiz_score': 58.58331128403415, 'homework_score': 47.44831568815929}
# {'name': 'Gennie Ratner', 'exam_score': 62.74309964110307, 'quiz_score': 92.18013849235186, 'homework_score': 53.11174468047395}
# {'name': 'Myrtle Wolfinger', 'exam_score': 73.93895528856032, 'quiz_score': 35.99397009906073, 'homework_score': 93.85826506506328}
# {'name': '', 'exam_score': 77.57315913088024, 'quiz_score': 13.28135073340091, 'homework_score': 67.27527802263116}
# {'name': 'aimee Zank', 'exam_score': 15.91636686717778, 'quiz_score': 96.12953798826392, 'homework_score': 18.92628947700149}
# {'name': 'Aurelia Menendez', 'exam_score': 5.105728872755167, 'quiz_score': 7.375913405784407, 'homework_score': 92.62414866541212}
# {'name': 'Corliss Zuk', 'exam_score': 76.45468797439878, 'quiz_score': 53.02642890026489, 'homework_score': 91.86573111689813}
# {'name': 'Bao Ziglar', 'exam_score': 37.22753032391262, 'quiz_score': 52.75139192596129, 'homework_score': 64.06863625194231}
# {'name': 'Zachary Langlais', 'exam_score': 62.20457822364115, 'quiz_score': 61.03733414415722, 'homework_score': 82.41688205392703}
# {'name': 'Wilburn Spiess', 'exam_score': 52.36963021569788, 'quiz_score': 96.5715450678789, 'homework_score': 61.35034001494281}
# {'name': 'Jenette Flanders', 'exam_score': 22.0445143239363, 'quiz_score': 22.43958080566196, 'homework_score': 63.38749542414235}
# {'name': 'Salena Olmos', 'exam_score': 0.8007809823509016, 'quiz_score': 44.71135559183793, 'homework_score': 65.17342981800904}
# {'name': 'Daphne Zheng', 'exam_score': 61.47626628718472, 'quiz_score': 21.99638326978255, 'homework_score': 88.2119997542672}
# {'name': 'Sanda Ryba', 'exam_score': 10.62413290291121, 'quiz_score': 3.544356815821981, 'homework_score': 57.10297055409504}
# {'name': 'Denisha Cast', 'exam_score': 2.723204808959712, 'quiz_score': 38.47056093169111, 'homework_score': 77.04035583743548}
# {'name': 'Marcus Blohm', 'exam_score': 64.47719204148157, 'quiz_score': 23.68353886432903, 'homework_score': 48.87355812474999}
# {'name': 'Quincy Danaher', 'exam_score': 40.53136904234401, 'quiz_score': 83.09270171511093, 'homework_score': 79.004550587978}
# {'name': 'Jessika Dagenais', 'exam_score': 96.93459855769822, 'quiz_score': 95.6756371543187, 'homework_score': 70.7887302106597}
# {'name': 'Alix Sherrill', 'exam_score': 43.67436243299881, 'quiz_score': 14.98112420690882, 'homework_score': 23.62416821198536}
# {'name': 'Tambra Mercure', 'exam_score': 62.61423873241083, 'quiz_score': 47.64776674251425, 'homework_score': 85.20578508528978}
# {'name': 'Dodie Staller', 'exam_score': 52.16051124848157, 'quiz_score': 83.51563143820728, 'homework_score': 63.88857636557489}
# {'name': 'Fletcher Mcconnell', 'exam_score': 24.98670635479149, 'quiz_score': 94.90809903126159, 'homework_score': 29.37194792367135}
# {'name': 'Verdell Sowinski', 'exam_score': 20.1442549902647, 'quiz_score': 47.66457425945161, 'homework_score': 77.87844292368344}
# {'name': 'Gisela Levin', 'exam_score': 15.88727528055548, 'quiz_score': 91.49884857295594, 'homework_score': 16.56032169309347}
# {'name': 'Tressa Schwing', 'exam_score': 54.53947018434061, 'quiz_score': 22.26443529294689, 'homework_score': 89.29532364756331}
# {'name': 'Rosana Vales', 'exam_score': 15.73156258820246, 'quiz_score': 33.70281347493842, 'homework_score': 62.79875994037851}
# {'name': 'Margart Vitello', 'exam_score': 99.33685767140612, 'quiz_score': 1.25322762871457, 'homework_score': 66.22827571617455}
# {'name': 'Tamika Schildgen', 'exam_score': 4.433956226109692, 'quiz_score': 65.50313785402548, 'homework_score': 89.5950384993947}
# {'name': 'Jesusa Rickenbacker', 'exam_score': 15.6237624645333, 'quiz_score': 7.856092232737, 'homework_score': 92.06889864132863}
# {'name': 'Rudolph Domingo', 'exam_score': 33.02956040417582, 'quiz_score': 35.99586495205484, 'homework_score': 91.06098699300175}
# {'name': 'Jonie Raby', 'exam_score': 7.307863391324043, 'quiz_score': 21.72514968277675, 'homework_score': 73.8284408290604}
# {'name': 'Edgar Sarkis', 'exam_score': 65.99888014434269, 'quiz_score': 58.75598946266268, 'homework_score': 75.06379354463246}
# {'name': 'Laureen Salomone', 'exam_score': 42.54322973844196, 'quiz_score': 33.03152379449381, 'homework_score': 77.52357320933667}
# {'name': 'Gwyneth Garling', 'exam_score': 44.29553481758053, 'quiz_score': 23.15599504527296, 'homework_score': 84.83695219376807}
# {'name': 'Kaila Deibler', 'exam_score': 20.85988856264308, 'quiz_score': 73.51120532285645, 'homework_score': 88.72483530139125}
# {'name': 'Tandra Meadows', 'exam_score': 19.07796402740767, 'quiz_score': 7.63846325490759, 'homework_score': 60.84655775785094}
# {'name': 'Gwen Honig', 'exam_score': 35.99646382910844, 'quiz_score': 74.46323507534565, 'homework_score': 90.95590422002779}
# {'name': 'Sadie Jernigan', 'exam_score': 6.14281392478545, 'quiz_score': 44.94102013771302, 'homework_score': 89.94407975401369}
# {'name': 'Carli Belvins', 'exam_score': 84.4361816750119, 'quiz_score': 1.702113040528119, 'homework_score': 88.48032660881387}
# {'name': 'Synthia Labelle', 'exam_score': 11.06312649271668, 'quiz_score': 89.27462706564148, 'homework_score': 41.1722010153017}
# {'name': 'Eugene Magdaleno', 'exam_score': 69.64543341032858, 'quiz_score': 17.46202326917462, 'homework_score': 39.41502498794787}
# {'name': 'Meagan Oakes', 'exam_score': 75.02808260234913, 'quiz_score': 35.45524188731927, 'homework_score': 75.84754202828454}
# {'name': 'Richelle Siemers', 'exam_score': 52.0158789874646, 'quiz_score': 19.25549934746802, 'homework_score': 68.33217408510437}
# {'name': 'Mariette Batdorf', 'exam_score': 91.38690728885123, 'quiz_score': 39.98831767858929, 'homework_score': 51.59702098442595}
# {'name': 'Rachell Aman', 'exam_score': 94.50988306850947, 'quiz_score': 5.68414255121964, 'homework_score': 64.46720717616572}
# {'name': 'Aleida Elsass', 'exam_score': 42.89558347656537, 'quiz_score': 94.10647660402866, 'homework_score': 30.56402201379193}
# {'name': 'Kayce Kenyon', 'exam_score': 54.00824880446614, 'quiz_score': 19.20300722190935, 'homework_score': 71.57649363606814}
# {'name': 'Ernestine Macfarland', 'exam_score': 9.666623747888858, 'quiz_score': 98.76040135775126, 'homework_score': 51.67453757397309}
# {'name': 'Houston Valenti', 'exam_score': 68.36209185504055, 'quiz_score': 15.83819664395878, 'homework_score': 81.7258704821604}
# {'name': 'Terica Brugger', 'exam_score': 97.822030541043, 'quiz_score': 91.56280485763772, 'homework_score': 62.01976292987356}
# {'name': 'Lady Lefevers', 'exam_score': 89.14702404133767, 'quiz_score': 11.85715160788611, 'homework_score': 87.70817474845785}
# {'name': 'Kurtis Jiles', 'exam_score': 38.84932631249875, 'quiz_score': 75.6856190089661, 'homework_score': 54.8262895255851}
# {'name': 'Barbera Lippman', 'exam_score': 10.1210778879972, 'quiz_score': 57.39236107118298, 'homework_score': 56.36039761834183}
# {'name': 'Dinah Sauve', 'exam_score': 9.660849614328693, 'quiz_score': 0.710026283123355, 'homework_score': 64.85706587155985}
# {'name': 'Alica Pasley', 'exam_score': 41.3852820348269, 'quiz_score': 87.0183839032626, 'homework_score': 37.22917544696978}
# {'name': 'Elizabet Kleine', 'exam_score': 23.35599596646158, 'quiz_score': 45.42989961046475, 'homework_score': 59.29421526983006}
# {'name': 'Tawana Oberg', 'exam_score': 79.24755285478162, 'quiz_score': 97.28127199858804, 'homework_score': 67.0528222080174}
# {'name': 'Malisa Jeanes', 'exam_score': 40.68676040665008, 'quiz_score': 52.60826688242043, 'homework_score': 94.67979508129564}
# {'name': 'Joel Rueter', 'exam_score': 21.78981361637835, 'quiz_score': 1.182228345865832, 'homework_score': 43.70843975739338}
# {'name': 'Tresa Sinha', 'exam_score': 52.22632020277269, 'quiz_score': 65.68701091428014, 'homework_score': 86.80410157346574}
# {'name': 'Danika Loeffler', 'exam_score': 80.13802901122058, 'quiz_score': 9.613195588726075, 'homework_score': 88.1580114788293}
# {'name': 'Chad Rahe', 'exam_score': 81.24054522370292, 'quiz_score': 17.44929152365297, 'homework_score': 82.77870021356301}
# {'name': 'Joaquina Arbuckle', 'exam_score': 35.43562368815135, 'quiz_score': 89.74640983145014, 'homework_score': 99.13868686848834}
# {'name': 'Vinnie Auerbach', 'exam_score': 57.26312067710243, 'quiz_score': 20.63583040849144, 'homework_score': 77.02638482252677}
# {'name': 'Dusti Lemmond', 'exam_score': 91.51968055194875, 'quiz_score': 50.37682668957234, 'homework_score': 51.53939113583016}
# {'name': 'Grady Zemke', 'exam_score': 10.37320113489379, 'quiz_score': 10.51344428386458, 'homework_score': 85.47180043794621}
# {'name': 'Vina Matsunaga', 'exam_score': 73.30054989074031, 'quiz_score': 4.21754550016783, 'homework_score': 56.31150858550771}
# {'name': 'Rubie Winton', 'exam_score': 36.1767454709986, 'quiz_score': 89.39738121365069, 'homework_score': 90.83326208217305}
# {'name': 'Whitley Fears', 'exam_score': 20.84454374176408, 'quiz_score': 57.14851257871499, 'homework_score': 99.77237745070993}
# {'name': 'Gena Riccio', 'exam_score': 81.49070346172086, 'quiz_score': 23.12653402998139, 'homework_score': 96.54590960898932}
# {'name': 'Kim Xu', 'exam_score': 29.1596029917098, 'quiz_score': 74.41836270655918, 'homework_score': 56.64965514703727}
# {'name': 'Merissa Mann', 'exam_score': 0.7300279717432967, 'quiz_score': 39.49170592908128, 'homework_score': 60.49619334485811}
# {'name': 'Jenise Mcguffie', 'exam_score': 83.68438201130127, 'quiz_score': 73.79931763764928, 'homework_score': 89.57200947426745}
# {'name': 'Cody Strouth', 'exam_score': 32.99854612126559, 'quiz_score': 78.61720316992681, 'homework_score': 89.62847560459466}
# {'name': 'Harriett Velarde', 'exam_score': 41.47988283148075, 'quiz_score': 95.69493673358075, 'homework_score': 83.03916048182315}
# {'name': 'Kam Senters', 'exam_score': 49.8822537074033, 'quiz_score': 45.29515361387067, 'homework_score': 68.88048980292801}
# {'name': 'Leonida Lafond', 'exam_score': 8.125073097960179, 'quiz_score': 0.2017888852605676, 'homework_score': 90.13081857264544}
# {'name': 'Devorah Smartt', 'exam_score': 23.94616611315642, 'quiz_score': 13.27371116063025, 'homework_score': 63.17281121561749}
# {'name': 'Leola Lundin', 'exam_score': 60.314725741828, 'quiz_score': 41.12327471818652, 'homework_score': 74.8699176311771}
# {'name': 'Tonia Surace', 'exam_score': 67.93405589675187, 'quiz_score': 31.49721116485943, 'homework_score': 82.36495908047985}
# {'name': 'Adrien Renda', 'exam_score': 64.16109192679477, 'quiz_score': 66.93730600935531, 'homework_score': 96.0560340227047}
# {'name': 'Efrain Claw', 'exam_score': 94.67153825229884, 'quiz_score': 82.30087932110595, 'homework_score': 75.86075840047938}
# {'name': 'Len Treiber', 'exam_score': 39.19832917406515, 'quiz_score': 98.71679252899352, 'homework_score': 44.8228929481132}
# {'name': 'Mariela Sherer', 'exam_score': 47.67196715489599, 'quiz_score': 41.55743490493954, 'homework_score': 70.4612811769744}
# {'name': 'Echo Pippins', 'exam_score': 18.09013691507853, 'quiz_score': 35.00306967250408, 'homework_score': 80.17965154316731}
# {'name': 'Linnie Weigel', 'exam_score': 52.44578368517977, 'quiz_score': 90.7775054046383, 'homework_score': 11.75008382913026}
# {'name': 'Santiago Dollins', 'exam_score': 52.04052571137036, 'quiz_score': 33.63300076481705, 'homework_score': 78.79257377604428}
# {'name': 'Tonisha Games', 'exam_score': 38.51269589995049, 'quiz_score': 31.16287577231703, 'homework_score': 79.15856355963004}
# {'name': 'Timothy Harrod', 'exam_score': 11.9075674046519, 'quiz_score': 20.51879961777022, 'homework_score': 64.85650354990375}
# {'name': 'Rae Kohout', 'exam_score': 82.11742562118049, 'quiz_score': 49.61295450928224, 'homework_score': 28.86823689842918}
# {'name': 'aimee Zank', 'exam_score': 1.463179736705023, 'quiz_score': 11.78273309957772, 'homework_score': 35.8740349954354}
# {'name': 'Aurelia Menendez', 'exam_score': 60.06045071030959, 'quiz_score': 52.79790691903873, 'homework_score': 71.76133439165544}
# {'name': 'Corliss Zuk', 'exam_score': 67.03077096065002, 'quiz_score': 6.301851677835235, 'homework_score': 66.28344683278382}
# {'name': 'Bao Ziglar', 'exam_score': 71.64343899778332, 'quiz_score': 24.80221293650313, 'homework_score': 42.26147058804812}
# {'name': 'Zachary Langlais', 'exam_score': 78.68385091304332, 'quiz_score': 90.2963101368042, 'homework_score': 34.41620148042529}
# {'name': 'Wilburn Spiess', 'exam_score': 44.87186330181261, 'quiz_score': 25.72395114668016, 'homework_score': 63.42288310628662}
# {'name': 'Jenette Flanders', 'exam_score': 37.32285459166097, 'quiz_score': 28.32634976913737, 'homework_score': 81.57115318686338}
# {'name': 'Salena Olmos', 'exam_score': 90.37826509157176, 'quiz_score': 42.48780666956811, 'homework_score': 96.52986171633331}
# {'name': 'Daphne Zheng', 'exam_score': 22.13583712862635, 'quiz_score': 14.63969941335069, 'homework_score': 75.94123677556644}
# {'name': 'Sanda Ryba', 'exam_score': 97.00509953654694, 'quiz_score': 97.80449632538915, 'homework_score': 25.27368532432955}
# {'name': 'Denisha Cast', 'exam_score': 45.61876862259409, 'quiz_score': 98.35723209418343, 'homework_score': 55.90835657173456}
# {'name': 'Marcus Blohm', 'exam_score': 78.42617835651868, 'quiz_score': 82.58372817930675, 'homework_score': 87.49924733328717}
# {'name': 'Quincy Danaher', 'exam_score': 54.29841278520669, 'quiz_score': 85.61270164694737, 'homework_score': 80.40732356118075}
# {'name': 'Jessika Dagenais', 'exam_score': 90.47179954427436, 'quiz_score': 90.3001402468489, 'homework_score': 95.17753772405909}
# {'name': 'Alix Sherrill', 'exam_score': 25.15924151998215, 'quiz_score': 68.64484047692098, 'homework_score': 24.68462152686763}
# {'name': 'Tambra Mercure', 'exam_score': 69.1565022533158, 'quiz_score': 3.311794422000724, 'homework_score': 45.03178973642521}
# {'name': 'Dodie Staller', 'exam_score': 7.772386442858281, 'quiz_score': 31.84300235104542, 'homework_score': 80.52136407989194}
# {'name': 'Fletcher Mcconnell', 'exam_score': 39.41011069729274, 'quiz_score': 81.13270307809924, 'homework_score': 97.70116640402922}
# {'name': 'Verdell Sowinski', 'exam_score': 62.12870233109035, 'quiz_score': 84.74586220889356, 'homework_score': 81.58947824932574}
# {'name': 'Gisela Levin', 'exam_score': 44.51211101958831, 'quiz_score': 0.6578497966368002, 'homework_score': 93.36341655949683}
# {'name': 'Tressa Schwing', 'exam_score': 42.17439799514388, 'quiz_score': 71.99314840599558, 'homework_score': 81.23972632069464}
# {'name': 'Rosana Vales', 'exam_score': 46.2289476258328, 'quiz_score': 98.34164225207036, 'homework_score': 36.18769746805938}
# {'name': 'Margart Vitello', 'exam_score': 75.04996547553947, 'quiz_score': 10.23046475899236, 'homework_score': 96.72520512117761}
# {'name': 'Tamika Schildgen', 'exam_score': 45.65432764125526, 'quiz_score': 64.32927049658846, 'homework_score': 83.53933351660562}
# {'name': 'Jesusa Rickenbacker', 'exam_score': 86.0319702155683, 'quiz_score': 1.967495200433389, 'homework_score': 61.10861071547914}
# {'name': 'Rudolph Domingo', 'exam_score': 74.75289335591543, 'quiz_score': 38.5413647805495, 'homework_score': 35.2554340953413}
# {'name': 'Jonie Raby', 'exam_score': 19.17861192576963, 'quiz_score': 76.3890359749654, 'homework_score': 44.39605672647002}
# {'name': 'Edgar Sarkis', 'exam_score': 8.606983261043888, 'quiz_score': 58.71180464203724, 'homework_score': 15.33726210596508}
# {'name': 'Laureen Salomone', 'exam_score': 3.677565278992456, 'quiz_score': 7.119462599229987, 'homework_score': 82.87308922617427}
# {'name': 'Gwyneth Garling', 'exam_score': 48.36644963899371, 'quiz_score': 10.37827022865908, 'homework_score': 93.26639335532833}
# {'name': 'Kaila Deibler', 'exam_score': 15.89771199662455, 'quiz_score': 56.93965183412178, 'homework_score': 66.64493295066322}
# {'name': 'Tandra Meadows', 'exam_score': 24.90138146001744, 'quiz_score': 28.8266541837344, 'homework_score': 97.16831550665721}
# {'name': 'Gwen Honig', 'exam_score': 87.14345376886205, 'quiz_score': 99.45824441135635, 'homework_score': 76.66460454219344}
# {'name': 'Sadie Jernigan', 'exam_score': 73.15861249943812, 'quiz_score': 2.987718065941702, 'homework_score': 82.54104198590488}
# {'name': 'Carli Belvins', 'exam_score': 7.112266875518214, 'quiz_score': 67.734668378287, 'homework_score': 88.99855402666871}
# {'name': 'Synthia Labelle', 'exam_score': 27.22049103148209, 'quiz_score': 31.28760039265919, 'homework_score': 79.23285425688643}
# {'name': 'Eugene Magdaleno', 'exam_score': 73.055900093666, 'quiz_score': 79.85621560462026, 'homework_score': 66.09143669040472}
# {'name': 'Meagan Oakes', 'exam_score': 86.06759716616264, 'quiz_score': 79.45097452834857, 'homework_score': 28.41090281547689}
# {'name': 'Richelle Siemers', 'exam_score': 34.64373397163318, 'quiz_score': 91.46799649446983, 'homework_score': 56.12615074082559}
# {'name': 'Mariette Batdorf', 'exam_score': 0.04381116979284005, 'quiz_score': 90.25774974259562, 'homework_score': 65.88612319625227}
# {'name': 'Rachell Aman', 'exam_score': 84.53009035375172, 'quiz_score': 25.25568126160764, 'homework_score': 70.42062575402956}
# {'name': 'Aleida Elsass', 'exam_score': 28.02518041693717, 'quiz_score': 95.25243105389065, 'homework_score': 68.05980405338909}
# {'name': 'Kayce Kenyon', 'exam_score': 44.62441703708117, 'quiz_score': 27.38208798553111, 'homework_score': 97.43587143437509}
# {'name': 'Ernestine Macfarland', 'exam_score': 15.29147856258362, 'quiz_score': 78.40698797039501, 'homework_score': 31.03031764716336}
# {'name': 'Houston Valenti', 'exam_score': 98.06441387027331, 'quiz_score': 0.8760893342659504, 'homework_score': 15.2177618920215}
# {'name': 'Terica Brugger', 'exam_score': 42.1011312120801, 'quiz_score': 41.73654145887228, 'homework_score': 18.91287189072117}
# {'name': 'Lady Lefevers', 'exam_score': 16.89237820123443, 'quiz_score': 65.97505910406456, 'homework_score': 48.42527123437286}
# {'name': 'Kurtis Jiles', 'exam_score': 92.96916908741805, 'quiz_score': 22.86854192921203, 'homework_score': 31.89793879453222}
# {'name': 'Barbera Lippman', 'exam_score': 35.43490750932609, 'quiz_score': 97.42074160188449, 'homework_score': 74.1092960902528}
# {'name': 'Dinah Sauve', 'exam_score': 96.64807532447064, 'quiz_score': 14.56470882270576, 'homework_score': 72.00519420743191}
# {'name': 'Alica Pasley', 'exam_score': 19.38544736721771, 'quiz_score': 88.70752686639557, 'homework_score': 60.62755218680213}
# {'name': 'Elizabet Kleine', 'exam_score': 86.81245449846962, 'quiz_score': 36.196443334522, 'homework_score': 77.94001750905642}
# {'name': 'Tawana Oberg', 'exam_score': 80.59006098671075, 'quiz_score': 93.28438118988183, 'homework_score': 93.12134003887978}
# {'name': 'Malisa Jeanes', 'exam_score': 33.44580005842922, 'quiz_score': 7.172746439960975, 'homework_score': 80.53328849494751}
# {'name': 'Joel Rueter', 'exam_score': 87.53636893952853, 'quiz_score': 92.70974674256513, 'homework_score': 61.79032586247813}
# {'name': 'Tresa Sinha', 'exam_score': 94.93136959210354, 'quiz_score': 72.32226123565266, 'homework_score': 77.248768811767}
# {'name': 'Danika Loeffler', 'exam_score': 21.54531707142236, 'quiz_score': 41.75962115078149, 'homework_score': 55.70195462204016}
# {'name': 'Chad Rahe', 'exam_score': 40.84572027366789, 'quiz_score': 29.22733629679561, 'homework_score': 93.12112348179406}
# {'name': 'Joaquina Arbuckle', 'exam_score': 28.66671659815553, 'quiz_score': 40.48858382583742, 'homework_score': 51.51393116681172}
# {'name': 'Vinnie Auerbach', 'exam_score': 95.45508256300009, 'quiz_score': 7.512188017365151, 'homework_score': 28.5905754294006}
# {'name': 'Dusti Lemmond', 'exam_score': 17.27725327681863, 'quiz_score': 83.24439414725833, 'homework_score': 81.84258722611811}
# {'name': 'Grady Zemke', 'exam_score': 51.91561300267121, 'quiz_score': 50.08349374829509, 'homework_score': 95.34139273570386}
# {'name': 'Vina Matsunaga', 'exam_score': 51.38190070034149, 'quiz_score': 34.63479282877322, 'homework_score': 46.27059093183421}
# {'name': 'Rubie Winton', 'exam_score': 7.176062073558509, 'quiz_score': 46.32426882511162, 'homework_score': 19.24312817599633}
# {'name': 'Whitley Fears', 'exam_score': 89.61845831842888, 'quiz_score': 82.44879156010508, 'homework_score': 96.57912148645883}
# {'name': 'Gena Riccio', 'exam_score': 67.58395308948619, 'quiz_score': 67.2413500951588, 'homework_score': 42.93471779899529}
# {'name': 'Kim Xu', 'exam_score': 19.96531774799065, 'quiz_score': 17.52966217224916, 'homework_score': 57.32983091095816}
# {'name': 'Merissa Mann', 'exam_score': 75.1949733626123, 'quiz_score': 52.56522605123723, 'homework_score': 94.67518167209815}
# {'name': 'Jenise Mcguffie', 'exam_score': 40.15210496060384, 'quiz_score': 90.60219950183566, 'homework_score': 51.58720341010564}
# {'name': 'Cody Strouth', 'exam_score': 4.784730508547719, 'quiz_score': 99.80348240553108, 'homework_score': 97.89665889862901}
# {'name': 'Harriett Velarde', 'exam_score': 33.7733570443736, 'quiz_score': 96.05228578589255, 'homework_score': 46.24926696413032}
# {'name': 'Kam Senters', 'exam_score': 81.56497719010976, 'quiz_score': 5.247410853581524, 'homework_score': 92.10078400854972}
# {'name': 'Leonida Lafond', 'exam_score': 92.10605086888438, 'quiz_score': 32.66022211621239, 'homework_score': 82.15588797092647}
# {'name': 'Devorah Smartt', 'exam_score': 69.60160495436016, 'quiz_score': 6.931507591998553, 'homework_score': 55.66005349294464}
# {'name': 'Leola Lundin', 'exam_score': 31.62936464207764, 'quiz_score': 91.28658941188532, 'homework_score': 93.71671632774428}
# {'name': 'Tonia Surace', 'exam_score': 80.93655069496523, 'quiz_score': 79.54620208144452, 'homework_score': 41.34308724166419}
# {'name': 'Adrien Renda', 'exam_score': 57.24794864351232, 'quiz_score': 19.5118228072558, 'homework_score': 70.71043448913191}
# {'name': 'Efrain Claw', 'exam_score': 55.41266579085205, 'quiz_score': 31.30359328252952, 'homework_score': 88.73134194093676}
# {'name': 'Len Treiber', 'exam_score': 21.21850173315791, 'quiz_score': 13.2282768150266, 'homework_score': 82.49842801247594}
# {'name': 'Mariela Sherer', 'exam_score': 61.20158144877323, 'quiz_score': 52.75657259917104, 'homework_score': 90.97004773806381}
# {'name': 'Echo Pippins', 'exam_score': 27.77924608896123, 'quiz_score': 85.1861976198818, 'homework_score': 92.50671800180454}
# {'name': 'Linnie Weigel', 'exam_score': 66.0349256424749, 'quiz_score': 67.57096025532985, 'homework_score': 38.33608066073369}
# {'name': 'Santiago Dollins', 'exam_score': 33.48242310776701, 'quiz_score': 60.49199094204558, 'homework_score': 87.02564768982076}
# {'name': 'Tonisha Games', 'exam_score': 29.13833807032966, 'quiz_score': 35.25054111123917, 'homework_score': 66.73047056293319}
# {'name': 'Timothy Harrod', 'exam_score': 93.23020013495737, 'quiz_score': 49.06010347848443, 'homework_score': 74.00788699415295}
# {'name': 'Rae Kohout', 'exam_score': 63.86894250781692, 'quiz_score': 55.81549538273672, 'homework_score': 59.13566011309437}
# {'name': 'Brain Lachapelle', 'exam_score': 2.013473187690951, 'quiz_score': 45.01802394825918, 'homework_score': 88.04712649447521}
# {'name': 'Toshiko Sabella', 'exam_score': 21.05570509531929, 'quiz_score': 26.43387483146958, 'homework_score': 42.80331214002496}
# {'name': 'Keesha Papadopoulos', 'exam_score': 82.35397321850031, 'quiz_score': 3.064361273717464, 'homework_score': 98.46867828216399}
# {'name': 'Cassi Heal', 'exam_score': 43.04310994985133, 'quiz_score': 0.006247360551892012, 'homework_score': 63.88558436723092}
# {'name': 'Osvaldo Hirt', 'exam_score': 67.44931456608883, 'quiz_score': 41.77986504201782, 'homework_score': 76.30879472084027}
# {'name': 'Ty Barbieri', 'exam_score': 38.43781607953586, 'quiz_score': 95.70340794272111, 'homework_score': 72.80272364761178}
# {'name': 'Ta Sikorski', 'exam_score': 30.02140506101446, 'quiz_score': 23.89164976236439, 'homework_score': 61.82907698626848}
# {'name': 'Lucinda Vanderburg', 'exam_score': 27.55843343656866, 'quiz_score': 11.45699271327768, 'homework_score': 75.53546873615787}
# {'name': 'Darby Wass', 'exam_score': 6.867644836612586, 'quiz_score': 63.4908039680606, 'homework_score': 85.41865347441522}
# {'name': 'Omar Bowdoin', 'exam_score': 8.58858127638702, 'quiz_score': 88.40377630359677, 'homework_score': 25.71387474240768}
# {'name': 'Milan Mcgavock', 'exam_score': 69.11554341921843, 'quiz_score': 10.2027724707151, 'homework_score': 24.87545552041663}
# {'name': 'Maren Scheider', 'exam_score': 94.4329121733663, 'quiz_score': 77.28263690107663, 'homework_score': 59.46326216544371}
# {'name': 'Carli Ector', 'exam_score': 88.18040268522668, 'quiz_score': 60.3111085581054, 'homework_score': 96.33612053785647}
# {'name': 'Jaclyn Morado', 'exam_score': 70.27627082122453, 'quiz_score': 56.78470387064279, 'homework_score': 47.48518298423097}
# {'name': 'Demarcus Audette', 'exam_score': 47.42608580155614, 'quiz_score': 44.83416623719906, 'homework_score': 39.01726616178844}
# {'name': 'Tania Hulett', 'exam_score': 21.84617015735916, 'quiz_score': 53.8568257735492, 'homework_score': 79.60533635579307}
# {'name': 'Mercedez Garduno', 'exam_score': 49.52877007656483, 'quiz_score': 44.55505066212384, 'homework_score': 81.50869746632009}
# {'name': 'Fleta Duplantis', 'exam_score': 84.37799696030743, 'quiz_score': 15.95792143439528, 'homework_score': 77.80745176713172}
# {'name': 'Brittny Warwick', 'exam_score': 69.54399888097534, 'quiz_score': 82.00469934215849, 'homework_score': 95.96446106607902}
# {'name': 'Shin Allbright', 'exam_score': 62.28388941877533, 'quiz_score': 85.26863799439475, 'homework_score': 88.9947941542333}
# {'name': 'Karry Petrarca', 'exam_score': 3.677125771067413, 'quiz_score': 40.39799056667404, 'homework_score': 14.38347127905983}
# {'name': 'Beckie Millington', 'exam_score': 69.52419218194589, 'quiz_score': 24.85411404016219, 'homework_score': 34.92039455520659}
# {'name': 'Mikaela Meidinger', 'exam_score': 63.75595052560389, 'quiz_score': 59.52298111997963, 'homework_score': 88.66481441499843}
# {'name': 'Flora Duell', 'exam_score': 40.68238966626067, 'quiz_score': 46.77972040308903, 'homework_score': 69.29400057020965}
# {'name': 'Nobuko Linzey', 'exam_score': 67.40792606687442, 'quiz_score': 58.58331128403415, 'homework_score': 47.44831568815929}
# {'name': 'Gennie Ratner', 'exam_score': 62.74309964110307, 'quiz_score': 92.18013849235186, 'homework_score': 53.11174468047395}
# {'name': 'Myrtle Wolfinger', 'exam_score': 73.93895528856032, 'quiz_score': 35.99397009906073, 'homework_score': 93.85826506506328}
# {'name': '', 'exam_score': 77.57315913088024, 'quiz_score': 13.28135073340091, 'homework_score': 67.27527802263116}
# {'name': 'aimee Zank', 'exam_score': 15.91636686717778, 'quiz_score': 96.12953798826392, 'homework_score': 18.92628947700149}
# {'name': 'Aurelia Menendez', 'exam_score': 5.105728872755167, 'quiz_score': 7.375913405784407, 'homework_score': 92.62414866541212}
# {'name': 'Corliss Zuk', 'exam_score': 76.45468797439878, 'quiz_score': 53.02642890026489, 'homework_score': 91.86573111689813}
# {'name': 'Bao Ziglar', 'exam_score': 37.22753032391262, 'quiz_score': 52.75139192596129, 'homework_score': 64.06863625194231}
# {'name': 'Zachary Langlais', 'exam_score': 62.20457822364115, 'quiz_score': 61.03733414415722, 'homework_score': 82.41688205392703}
# {'name': 'Wilburn Spiess', 'exam_score': 52.36963021569788, 'quiz_score': 96.5715450678789, 'homework_score': 61.35034001494281}
# {'name': 'Jenette Flanders', 'exam_score': 22.0445143239363, 'quiz_score': 22.43958080566196, 'homework_score': 63.38749542414235}
# {'name': 'Salena Olmos', 'exam_score': 0.8007809823509016, 'quiz_score': 44.71135559183793, 'homework_score': 65.17342981800904}
# {'name': 'Daphne Zheng', 'exam_score': 61.47626628718472, 'quiz_score': 21.99638326978255, 'homework_score': 88.2119997542672}
# {'name': 'Sanda Ryba', 'exam_score': 10.62413290291121, 'quiz_score': 3.544356815821981, 'homework_score': 57.10297055409504}
# {'name': 'Denisha Cast', 'exam_score': 2.723204808959712, 'quiz_score': 38.47056093169111, 'homework_score': 77.04035583743548}
# {'name': 'Marcus Blohm', 'exam_score': 64.47719204148157, 'quiz_score': 23.68353886432903, 'homework_score': 48.87355812474999}
# {'name': 'Quincy Danaher', 'exam_score': 40.53136904234401, 'quiz_score': 83.09270171511093, 'homework_score': 79.004550587978}
# {'name': 'Jessika Dagenais', 'exam_score': 96.93459855769822, 'quiz_score': 95.6756371543187, 'homework_score': 70.7887302106597}
# {'name': 'Alix Sherrill', 'exam_score': 43.67436243299881, 'quiz_score': 14.98112420690882, 'homework_score': 23.62416821198536}
# {'name': 'Tambra Mercure', 'exam_score': 62.61423873241083, 'quiz_score': 47.64776674251425, 'homework_score': 85.20578508528978}
# {'name': 'Dodie Staller', 'exam_score': 52.16051124848157, 'quiz_score': 83.51563143820728, 'homework_score': 63.88857636557489}
# {'name': 'Fletcher Mcconnell', 'exam_score': 24.98670635479149, 'quiz_score': 94.90809903126159, 'homework_score': 29.37194792367135}
# {'name': 'Verdell Sowinski', 'exam_score': 20.1442549902647, 'quiz_score': 47.66457425945161, 'homework_score': 77.87844292368344}
# {'name': 'Gisela Levin', 'exam_score': 15.88727528055548, 'quiz_score': 91.49884857295594, 'homework_score': 16.56032169309347}
# {'name': 'Tressa Schwing', 'exam_score': 54.53947018434061, 'quiz_score': 22.26443529294689, 'homework_score': 89.29532364756331}
# {'name': 'Rosana Vales', 'exam_score': 15.73156258820246, 'quiz_score': 33.70281347493842, 'homework_score': 62.79875994037851}
# {'name': 'Margart Vitello', 'exam_score': 99.33685767140612, 'quiz_score': 1.25322762871457, 'homework_score': 66.22827571617455}
# {'name': 'Tamika Schildgen', 'exam_score': 4.433956226109692, 'quiz_score': 65.50313785402548, 'homework_score': 89.5950384993947}
# {'name': 'Jesusa Rickenbacker', 'exam_score': 15.6237624645333, 'quiz_score': 7.856092232737, 'homework_score': 92.06889864132863}
# {'name': 'Rudolph Domingo', 'exam_score': 33.02956040417582, 'quiz_score': 35.99586495205484, 'homework_score': 91.06098699300175}
# {'name': 'Jonie Raby', 'exam_score': 7.307863391324043, 'quiz_score': 21.72514968277675, 'homework_score': 73.8284408290604}
# {'name': 'Edgar Sarkis', 'exam_score': 65.99888014434269, 'quiz_score': 58.75598946266268, 'homework_score': 75.06379354463246}
# {'name': 'Laureen Salomone', 'exam_score': 42.54322973844196, 'quiz_score': 33.03152379449381, 'homework_score': 77.52357320933667}
# {'name': 'Gwyneth Garling', 'exam_score': 44.29553481758053, 'quiz_score': 23.15599504527296, 'homework_score': 84.83695219376807}
# {'name': 'Kaila Deibler', 'exam_score': 20.85988856264308, 'quiz_score': 73.51120532285645, 'homework_score': 88.72483530139125}
# {'name': 'Tandra Meadows', 'exam_score': 19.07796402740767, 'quiz_score': 7.63846325490759, 'homework_score': 60.84655775785094}
# {'name': 'Gwen Honig', 'exam_score': 35.99646382910844, 'quiz_score': 74.46323507534565, 'homework_score': 90.95590422002779}
# {'name': 'Sadie Jernigan', 'exam_score': 6.14281392478545, 'quiz_score': 44.94102013771302, 'homework_score': 89.94407975401369}
# {'name': 'Carli Belvins', 'exam_score': 84.4361816750119, 'quiz_score': 1.702113040528119, 'homework_score': 88.48032660881387}
# {'name': 'Synthia Labelle', 'exam_score': 11.06312649271668, 'quiz_score': 89.27462706564148, 'homework_score': 41.1722010153017}
# {'name': 'Eugene Magdaleno', 'exam_score': 69.64543341032858, 'quiz_score': 17.46202326917462, 'homework_score': 39.41502498794787}
# {'name': 'Meagan Oakes', 'exam_score': 75.02808260234913, 'quiz_score': 35.45524188731927, 'homework_score': 75.84754202828454}
# {'name': 'Richelle Siemers', 'exam_score': 52.0158789874646, 'quiz_score': 19.25549934746802, 'homework_score': 68.33217408510437}
# {'name': 'Mariette Batdorf', 'exam_score': 91.38690728885123, 'quiz_score': 39.98831767858929, 'homework_score': 51.59702098442595}
# {'name': 'Rachell Aman', 'exam_score': 94.50988306850947, 'quiz_score': 5.68414255121964, 'homework_score': 64.46720717616572}
# {'name': 'Aleida Elsass', 'exam_score': 42.89558347656537, 'quiz_score': 94.10647660402866, 'homework_score': 30.56402201379193}
# {'name': 'Kayce Kenyon', 'exam_score': 54.00824880446614, 'quiz_score': 19.20300722190935, 'homework_score': 71.57649363606814}
# {'name': 'Ernestine Macfarland', 'exam_score': 9.666623747888858, 'quiz_score': 98.76040135775126, 'homework_score': 51.67453757397309}
# {'name': 'Houston Valenti', 'exam_score': 68.36209185504055, 'quiz_score': 15.83819664395878, 'homework_score': 81.7258704821604}
# {'name': 'Terica Brugger', 'exam_score': 97.822030541043, 'quiz_score': 91.56280485763772, 'homework_score': 62.01976292987356}
# {'name': 'Lady Lefevers', 'exam_score': 89.14702404133767, 'quiz_score': 11.85715160788611, 'homework_score': 87.70817474845785}
# {'name': 'Kurtis Jiles', 'exam_score': 38.84932631249875, 'quiz_score': 75.6856190089661, 'homework_score': 54.8262895255851}
# {'name': 'Barbera Lippman', 'exam_score': 10.1210778879972, 'quiz_score': 57.39236107118298, 'homework_score': 56.36039761834183}
# {'name': 'Dinah Sauve', 'exam_score': 9.660849614328693, 'quiz_score': 0.710026283123355, 'homework_score': 64.85706587155985}
# {'name': 'Alica Pasley', 'exam_score': 41.3852820348269, 'quiz_score': 87.0183839032626, 'homework_score': 37.22917544696978}
# {'name': 'Elizabet Kleine', 'exam_score': 23.35599596646158, 'quiz_score': 45.42989961046475, 'homework_score': 59.29421526983006}
# {'name': 'Tawana Oberg', 'exam_score': 79.24755285478162, 'quiz_score': 97.28127199858804, 'homework_score': 67.0528222080174}
# {'name': 'Malisa Jeanes', 'exam_score': 40.68676040665008, 'quiz_score': 52.60826688242043, 'homework_score': 94.67979508129564}
# {'name': 'Joel Rueter', 'exam_score': 21.78981361637835, 'quiz_score': 1.182228345865832, 'homework_score': 43.70843975739338}
# {'name': 'Tresa Sinha', 'exam_score': 52.22632020277269, 'quiz_score': 65.68701091428014, 'homework_score': 86.80410157346574}
# {'name': 'Danika Loeffler', 'exam_score': 80.13802901122058, 'quiz_score': 9.613195588726075, 'homework_score': 88.1580114788293}
# {'name': 'Chad Rahe', 'exam_score': 81.24054522370292, 'quiz_score': 17.44929152365297, 'homework_score': 82.77870021356301}
# {'name': 'Joaquina Arbuckle', 'exam_score': 35.43562368815135, 'quiz_score': 89.74640983145014, 'homework_score': 99.13868686848834}
# {'name': 'Vinnie Auerbach', 'exam_score': 57.26312067710243, 'quiz_score': 20.63583040849144, 'homework_score': 77.02638482252677}
# {'name': 'Dusti Lemmond', 'exam_score': 91.51968055194875, 'quiz_score': 50.37682668957234, 'homework_score': 51.53939113583016}
# {'name': 'Grady Zemke', 'exam_score': 10.37320113489379, 'quiz_score': 10.51344428386458, 'homework_score': 85.47180043794621}
# {'name': 'Vina Matsunaga', 'exam_score': 73.30054989074031, 'quiz_score': 4.21754550016783, 'homework_score': 56.31150858550771}
# {'name': 'Rubie Winton', 'exam_score': 36.1767454709986, 'quiz_score': 89.39738121365069, 'homework_score': 90.83326208217305}
# {'name': 'Whitley Fears', 'exam_score': 20.84454374176408, 'quiz_score': 57.14851257871499, 'homework_score': 99.77237745070993}
# {'name': 'Gena Riccio', 'exam_score': 81.49070346172086, 'quiz_score': 23.12653402998139, 'homework_score': 96.54590960898932}
# {'name': 'Kim Xu', 'exam_score': 29.1596029917098, 'quiz_score': 74.41836270655918, 'homework_score': 56.64965514703727}
# {'name': 'Merissa Mann', 'exam_score': 0.7300279717432967, 'quiz_score': 39.49170592908128, 'homework_score': 60.49619334485811}
# {'name': 'Jenise Mcguffie', 'exam_score': 83.68438201130127, 'quiz_score': 73.79931763764928, 'homework_score': 89.57200947426745}
# {'name': 'Cody Strouth', 'exam_score': 32.99854612126559, 'quiz_score': 78.61720316992681, 'homework_score': 89.62847560459466}
# {'name': 'Harriett Velarde', 'exam_score': 41.47988283148075, 'quiz_score': 95.69493673358075, 'homework_score': 83.03916048182315}
# {'name': 'Kam Senters', 'exam_score': 49.8822537074033, 'quiz_score': 45.29515361387067, 'homework_score': 68.88048980292801}
# {'name': 'Leonida Lafond', 'exam_score': 8.125073097960179, 'quiz_score': 0.2017888852605676, 'homework_score': 90.13081857264544}
# {'name': 'Devorah Smartt', 'exam_score': 23.94616611315642, 'quiz_score': 13.27371116063025, 'homework_score': 63.17281121561749}
# {'name': 'Leola Lundin', 'exam_score': 60.314725741828, 'quiz_score': 41.12327471818652, 'homework_score': 74.8699176311771}
# {'name': 'Tonia Surace', 'exam_score': 67.93405589675187, 'quiz_score': 31.49721116485943, 'homework_score': 82.36495908047985}
# {'name': 'Adrien Renda', 'exam_score': 64.16109192679477, 'quiz_score': 66.93730600935531, 'homework_score': 96.0560340227047}
# {'name': 'Efrain Claw', 'exam_score': 94.67153825229884, 'quiz_score': 82.30087932110595, 'homework_score': 75.86075840047938}
# {'name': 'Len Treiber', 'exam_score': 39.19832917406515, 'quiz_score': 98.71679252899352, 'homework_score': 44.8228929481132}
# {'name': 'Mariela Sherer', 'exam_score': 47.67196715489599, 'quiz_score': 41.55743490493954, 'homework_score': 70.4612811769744}
# {'name': 'Echo Pippins', 'exam_score': 18.09013691507853, 'quiz_score': 35.00306967250408, 'homework_score': 80.17965154316731}
# {'name': 'Linnie Weigel', 'exam_score': 52.44578368517977, 'quiz_score': 90.7775054046383, 'homework_score': 11.75008382913026}
# {'name': 'Santiago Dollins', 'exam_score': 52.04052571137036, 'quiz_score': 33.63300076481705, 'homework_score': 78.79257377604428}
# {'name': 'Tonisha Games', 'exam_score': 38.51269589995049, 'quiz_score': 31.16287577231703, 'homework_score': 79.15856355963004}
# {'name': 'Timothy Harrod', 'exam_score': 11.9075674046519, 'quiz_score': 20.51879961777022, 'homework_score': 64.85650354990375}
# {'name': 'Rae Kohout', 'exam_score': 82.11742562118049, 'quiz_score': 49.61295450928224, 'homework_score': 28.86823689842918}

# %%
#1)Find the student name who scored maximum scores in all (exam, quiz and homework)?
t=rec_2.find_one(sort=[("exam_score",-1)])
print(t['name'])
t=rec_2.find_one(sort=[("quiz_score",-1)])
print(t['name'])
t=rec_2.find_one(sort=[("homework_score",-1)])
print(t['name'])
# Out:
# Margart Vitello
# Cody Strouth
# Whitley Fears

# %%
#2)Find students who scored below average in the exam and pass mark is 40%?

avg=df_2["exam_score"].mean()
pasMark=40

p=[]
for i in rec_2.find({"$and":[{"exam_score":{"$lt":avg}},{"exam_score":{"$gt":pasMark}}]},{'_id':0,'name':1}):
  p.append(i)

df_a=pd.DataFrame(p)
df_a
# Out:
#                 name
# 0     Wilburn Spiess
# 1       Denisha Cast
# 2       Gisela Levin
# 3     Tressa Schwing
# 4       Rosana Vales
# 5   Tamika Schildgen
# 6    Gwyneth Garling
# 7       Kayce Kenyon
# 8     Terica Brugger
# 9          Chad Rahe
# 10   Jenise Mcguffie
# 11        Cassi Heal
# 12  Demarcus Audette
# 13       Flora Duell
# 14    Quincy Danaher
# 15     Alix Sherrill
# 16  Laureen Salomone
# 17   Gwyneth Garling
# 18     Aleida Elsass
# 19      Alica Pasley
# 20     Malisa Jeanes
# 21  Harriett Velarde
# 22    Mariela Sherer
# 23    Wilburn Spiess
# 24      Denisha Cast
# 25      Gisela Levin
# 26    Tressa Schwing
# 27      Rosana Vales
# 28  Tamika Schildgen
# 29   Gwyneth Garling
# 30      Kayce Kenyon
# 31    Terica Brugger
# 32         Chad Rahe
# 33   Jenise Mcguffie
# 34        Cassi Heal
# 35  Demarcus Audette
# 36       Flora Duell
# 37    Quincy Danaher
# 38     Alix Sherrill
# 39  Laureen Salomone
# 40   Gwyneth Garling
# 41     Aleida Elsass
# 42      Alica Pasley
# 43     Malisa Jeanes
# 44  Harriett Velarde
# 45    Mariela Sherer

# %%
#3)Find students who scored below pass mark and assigned them as fail, and above pass mark as pass in all the categories.
df_3=df_2
t1=[]
t2=[]
t3=[]

t1=np.where((df_2['exam_score']>pasMark),'Pass','Fail')
df_3.insert(loc=3,
            column='exam_grade',
            value=t1)

t2=np.where((df_2['quiz_score']>pasMark),'Pass','Fail')
df_3.insert(loc=4,column='quiz_grade',value=t2)

t3=np.where((df_2['homework_score']>pasMark),'Pass','Fail')
df_3.insert(loc=6,column='homework_grade',value=t3)
df_3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-2d4ebfe861a7> in <module>
#       8 df_3.insert(loc=3,
#       9             column='exam_grade',
# ---> 10             value=t1)
#      11
#      12 t2=np.where((df_2['quiz_score']>pasMark),'Pass','Fail')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    4412         if not allow_duplicates and column in self.columns:
#    4413             # Should this be a different kind of error??
# -> 4414             raise ValueError(f"cannot insert {column}, already exists")
#    4415         if not isinstance(loc, int):
#    4416             raise TypeError("loc must be int")
#
# ValueError: cannot insert exam_grade, already exists

# %%
#4).Find the total and average of the exam, quiz and homework and store them in a separate collection.

df_3=df_2
t1=[]
t2=[]
t3=[]

t1 = np.where((df_2['exam_score'] > pasMark), "Pass", "Fail")
df_3.insert(loc = 2,
          column = 'exam_grade',
          value = t1)

t2 = np.where((df_2['quiz_score'] > pasMark), "Pass", "Fail")
df_3.insert(loc = 4,
          column = 'quiz_grade',
          value = t2)

t3 = np.where((df_2['homework_score'] > pasMark), "Pass", "Fail")
df_3.insert(loc = 6,
          column = 'homework_grade',
          value = t3)

df_3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-2e1d305e5eb5> in <module>
#       7 df_3.insert(loc = 2,
#       8           column = 'exam_grade',
# ----> 9           value = t1)
#      10
#      11 t2 = np.where((df_2['quiz_score'] > pasMark), "Pass", "Fail")
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    4412         if not allow_duplicates and column in self.columns:
#    4413             # Should this be a different kind of error??
# -> 4414             raise ValueError(f"cannot insert {column}, already exists")
#    4415         if not isinstance(loc, int):
#    4416             raise TypeError("loc must be int")
#
# ValueError: cannot insert exam_grade, already exists

# %%
#5)Create a new collection which consists of students who scored below average and above 40% in all the categories.

emean=df_2["exam_score"].mean()
qmean=df_2["quiz_score"].mean()
hmean=df_2["homework_score"].mean()
x=[]
y=[]
z=[]

pasMark=40

for i in rec_4.find({"$and":[{"exam_score":{"$gt":pasMark}},{"exam_score":{"$lt":emean}}]},{'_id':0,"quiz_score":0,"homework_score":0}):
  x.append(i)
for i in rec_4.find({"$and":[{"quiz_score":{"$gt":pasMark}},{"quiz_score":{"$lt":qmean}}]},{'_id':0,"exam_score":0,"homework_score":0}):
  y.append(i)
for i in rec_4.find({"$and":[{"homework_score":{"$gt":pasMark}},{"homework_score":{"$lt":hmean}}]},{'_id':0,"exam_score":0,"quiz_score":0}):
  z.append(i)

df_5=pd.DataFrame(x)
df_6=pd.DataFrame(y)
df_7=pd.DataFrame(z)

# %%
col_5=database_1["exam_score"]
rec_5=col_5["exam_score"]
rec_5.insert_many(exportMongo(df_5))

col_6=database_1["quiz_score"]
rec_6=col_6["quiz_score"]
rec_6.insert_many(exportMongo(df_6))

col_7=database_1["homework_score"]
rec_7=col_7["homework_score"]
rec_7.insert_many(exportMongo(df_7))

for i in rec_5.find({},{"_id":0,"name":1,"exam_score":1}):
  print(i)

for i in rec_6.find({},{"_id":0,"name":1,"quiz_score":1}):
  print(i)
for i in rec_7.find({},{"_id":0,"name":1,"homework_score":1}):
  print(i)

# %%
#6)Create a new collection which consists of students who scored below the fail mark in all the categories.

failMark=39.9999
col_8=database_1["non_passed"]
rec_8=col_8["non_passed"]
t=[]

for i in rec_2.find({"$or":[{"$or":[{"homework_score":{"$lt":failMark}},{"quiz_score":{"$lt":failMark}}]},{"_id":0}):
  t.append(i)
df_8=pd.DataFrame(t)
rec_8.insert_many(exportMongo(df_8))

for i in rec_8.find({},{'_id':0}):
  print(i)

# %%
#7)Create a new collection which consists of students who scored above pass mark in all the categories.

col_9=database_1["passed_stu"]
rec_9=col_9["passed_stu"]
t=[]

for i in rec_2.find({"$and":[{"$and":[{"homework_score":{"$gt":pasMark}},{"quiz_score":{"$gt":pasMark}}]},{"_id":0}}):
  t.append(i)

df_9=pd.DataFrame(t)
rec_9.insert_many(exportMongo(df_9))

for i in rec_9.find({},{'_id':0}):
  print(i)

# %%
#Telephone Directory CRUD Operation

db=Elan["Tel"]
collection=db["crud"]

# %%
#For CRUD operation, create a directory which has fields like Name, Phone number, Place etc.,

db.crud.insert_one({
                 Name:"Raja",
                 Phone Number:"7289023145",
                 Place:"Chennai",
                 DOB:"18/02/1960"})

db.crud.insert_many([{
                  Name:"Anbu",
                  Phone Number:"8913423456",
                  Place:"Madurai",
                  DOB:"19/10/1989"},
                  {Name:"Rakesh",
                  Phone Number:"9913429456",
                  Place:"Malta",
                  DOB:"11/10/1988"},
                  {Name:"Kathir",
                  Phone Number:"6998423456",
                  Place:"Pondy",
                  DOB:"01/06/2000"},
                  {Name:"Ranjith",
                  Phone Number:"7795642345",
                  Place:"Kerala",
                  DOB:"12/10/1990"},
                  {Name:"Dinesh",
                  Phone Number:"7313423423",
                  Place:"Sweden",
                  DOB:"15/11/1995"}])

# %%
#Make a query to find records you just created.
db.crud.find()
db.crud.find({"Name":"Dinesh"})

# %%
#Modify the records, use the update_one() method. The update_one() method requires two arguments, query and update.

db.crud.update_one({Name:"Ranjith"},{$set:{Place:"America"}})

db.crud.update_many({Place:"Pondy"},{$set:{DOB:"15/02/1990"}})

#Replace one
db.crud.replace_one({Name:"Dinesh"},{Name:"Kevin"})

# %%
#Delete the record, use delete_one() method. delete_one() requires a query parameter which specifies the document to delete.

db.crud.delete_one({Name:"kathir"})
db.crud.delete_many({Place:"Pondy"})
